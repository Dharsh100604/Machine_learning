# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharsh100604/Machine_learning/blob/main/Iris_Gradientboost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
y_train=df['Species']

# %%
df.drop(labels='Species',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# dtype: int64

# %%
train_test_dummies=pd.get_dummies(df,columns=['SepalLengthCm'])

# %%
train_test_dummies.isnull().sum()
# Out:
# Id                   0
# SepalWidthCm         0
# PetalLengthCm        0
# PetalWidthCm         0
# SepalLengthCm_4.3    0
# SepalLengthCm_4.4    0
# SepalLengthCm_4.5    0
# SepalLengthCm_4.6    0
# SepalLengthCm_4.7    0
# SepalLengthCm_4.8    0
# SepalLengthCm_4.9    0
# SepalLengthCm_5.0    0
# SepalLengthCm_5.1    0
# SepalLengthCm_5.2    0
# SepalLengthCm_5.3    0
# SepalLengthCm_5.4    0
# SepalLengthCm_5.5    0
# SepalLengthCm_5.6    0
# SepalLengthCm_5.7    0
# SepalLengthCm_5.8    0
# SepalLengthCm_5.9    0
# SepalLengthCm_6.0    0
# SepalLengthCm_6.1    0
# SepalLengthCm_6.2    0
# SepalLengthCm_6.3    0
# SepalLengthCm_6.4    0
# SepalLengthCm_6.5    0
# SepalLengthCm_6.6    0
# SepalLengthCm_6.7    0
# SepalLengthCm_6.8    0
# SepalLengthCm_6.9    0
# SepalLengthCm_7.0    0
# SepalLengthCm_7.1    0
# SepalLengthCm_7.2    0
# SepalLengthCm_7.3    0
# SepalLengthCm_7.4    0
# SepalLengthCm_7.6    0
# SepalLengthCm_7.7    0
# SepalLengthCm_7.9    0
# dtype: int64

# %%
train_test_dummies
# Out:
#       Id  SepalWidthCm  PetalLengthCm  PetalWidthCm  SepalLengthCm_4.3  \
# 0      1           3.5            1.4           0.2                  0
# 1      2           3.0            1.4           0.2                  0
# 2      3           3.2            1.3           0.2                  0
# 3      4           3.1            1.5           0.2                  0
# 4      5           3.6            1.4           0.2                  0
# ..   ...           ...            ...           ...                ...
# 145  146           3.0            5.2           2.3                  0
# 146  147           2.5            5.0           1.9                  0
# 147  148           3.0            5.2           2.0                  0
# 148  149           3.4            5.4           2.3                  0
# 149  150           3.0            5.1           1.8                  0
#
#      SepalLengthCm_4.4  SepalLengthCm_4.5  SepalLengthCm_4.6  \
# ...

# %%
X_train=df.values[0:75]
X_test=df.values[100:]

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()
X_train_scale=scale.fit_transform(X_train)
X_test_scale=scale.transform(X_test)

# %%
from sklearn.model_selection import train_test_split
y_train_sub = y_train[:75]
X_train_sub, X_validation_sub, y_train_sub, y_validation_sub = train_test_split(X_train_scale, y_train_sub, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report,confusion_matrix

# %%
learning_rates = [0.05, 0.1, 4, 0.5, 0.75, 1]
for learning_rate in learning_rates:
    gb = GradientBoostingClassifier(n_estimators=20, learning_rate = learning_rate, random_state = 0)
    gb.fit(X_train_sub, y_train_sub)
    print("Learning rate: ", learning_rate)
    print("Accuracy score (training): {0:.3f}".format(gb.score(X_train_sub, y_train_sub)))
    print("Accuracy score (validation): {0:.3f}".format(gb.score(X_validation_sub, y_validation_sub)))
    print()
# Out:
# Learning rate:  0.05
# Accuracy score (training): 1.000
# Accuracy score (validation): 1.000
#
# Learning rate:  0.1
# Accuracy score (training): 1.000
# Accuracy score (validation): 1.000
#
# Learning rate:  4
# Accuracy score (training): 1.000
# Accuracy score (validation): 1.000
#
# Learning rate:  0.5
# Accuracy score (training): 1.000
# Accuracy score (validation): 1.000
#
# Learning rate:  0.75
# Accuracy score (training): 1.000
# Accuracy score (validation): 1.000
#
# Learning rate:  1
# Accuracy score (training): 1.000
# Accuracy score (validation): 1.000
