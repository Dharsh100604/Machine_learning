# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharsh100604/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas**
# * function and opperations
# * polar(big data)-> dataframe lib for rust and python
# * pyspark(tool)->for data process
# * roboflow
# * label->colm name
# * data manipulate
# ****
# Dataset
# * collect
# * oraganise
# * label
# * process
# ****
# * series-> 1D
# * Dataframe->2D
# ****
# * 80->
# * 20->testing
# ****
# * numpy -> only accessed with index
# * pandas -> accessed with both column and row

# %% [markdown]
# **CPU and GPU**
# * GPU -> parallel processing
# * GPU cores are less powerful than CPU cores and have less memory.

# %%
import numpy as np
import pandas as pd

# %%
a=np.array([1,2,3,4,5])
print(a)
type(a)
# Out:
# [1 2 3 4 5]
# numpy.ndarray

# %%
a[1]
# Out:
# 2

# %%
s=pd.Series([1,2,3,4,5])
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s[3]
# Out:
# 4

# %%
s.drop(3)
# Out:
# 0    1
# 1    2
# 2    3
# 4    5
# dtype: int64

# %%
s.drop(2,inplace=True) #3rd index will be deleted

# %%
s
# Out:
# 0    1
# 1    2
# 3    4
# 4    5
# dtype: int64

# %%
s.index
# Out:
# Int64Index([0, 1, 3, 4], dtype='int64')

# %%
s.loc[4]
# Out:
# 5

# %%
s.iloc[2]
# Out:
# 4

# %%
a=pd.Series([1,2,3,4],index=['a','b','b','d'])
a
# Out:
# a    1
# b    2
# b    3
# d    4
# dtype: int64

# %%
a['b']
# Out:
# b    2
# b    3
# dtype: int64

# %%
a.iloc[3]
# Out:
# 4

# %%
a.loc['b']
# Out:
# b    2
# b    3
# dtype: int64

# %%
data=[['dharsh',19,'10-6-2004'],['Dhivs',18,'21-07-2004'],['Bava',20,'26-11-2003']]
data
# Out:
# [['dharsh', 19, '10-6-2004'],
#  ['Dhivs', 18, '21-07-2004'],
#  ['Bava', 20, '26-11-2003']]

# %%
df=pd.DataFrame(data) #[data]->will take as 1D
df
# Out:
#         0   1           2
# 0  dharsh  19   10-6-2004
# 1   Dhivs  18  21-07-2004
# 2    Bava  20  26-11-2003

# %%
df[1:2]
# Out:
#        0   1           2
# 1  Dhivs  18  21-07-2004

# %%
df[0][0]
# Out:
# 'dharsh'

# %%
df[2]
# Out:
# 0     10-6-2004
# 1    21-07-2004
# 2    26-11-2003
# Name: 2, dtype: object

# %%
df=pd.DataFrame(data,columns=['Name','Age','DOB'])

# %%
df['Name'] #case sensitive
# Out:
# 0    dharsh
# 1     Dhivs
# 2      Bava
# Name: Name, dtype: object

# %%
df['Name'][0]
# Out:
# 'dharsh'

# %%
df.loc[0,'Name']
# Out:
# 'dharsh'

# %%
df.iloc[:1]
# Out:
#      Name  Age        DOB
# 0  dharsh   19  10-6-2004

# %%
a=pd.Series([1,2,3,4])
a.plot.bar()
# Out:
# <Axes: >

# %%
a.hist(bins=2)
# Out:
# <Axes: >

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
s=a.to_numpy()

# %%
type(s)
# Out:
# numpy.ndarray

# %%
df.tail(-2)
# Out:
#    Name  Age         DOB
# 2  Bava   20  26-11-2003

# %% [markdown]
# * none,' ', '' , '-' , '?' ,'Nil',np.nan (not a number)

# %%
df
# Out:
#      Name  Age         DOB
# 0  dharsh   19   10-6-2004
# 1   Dhivs   18  21-07-2004
# 2    Bava   20  26-11-2003

# %%
df.isnull().sum()
# Out:
# Name    0
# Age     0
# DOB     0
# dtype: int64

# %%
data=[['dharsh',19,'10-6-2004'],['Dhivs',None,'21-07-2004'],['Bava',20,'26-11-2003'],['a',0,'None'],['b',0,None],['D','NaN','21-07-2004'],['np.nan',' ','2 ']]
df=pd.DataFrame(data)
df
# Out:
#         0     1           2
# 0  dharsh    19   10-6-2004
# 1   Dhivs  None  21-07-2004
# 2    Bava    20  26-11-2003
# 3       a     0        None
# 4       b     0        None
# 5       D   NaN  21-07-2004
# 6  np.nan                2

# %%
df.isnull().sum()
# Out:
# 0    0
# 1    1
# 2    1
# dtype: int64

# %%
df.dropna()
# Out:
#         0    1           2
# 0  dharsh   19   10-6-2004
# 2    Bava   20  26-11-2003
# 3       a    0        None
# 5       D  NaN  21-07-2004
# 6  np.nan               2

# %%
df.drop?

# %%
df=pd.DataFrame(data,columns=['Name','Age','DOB'])

# %%
df.drop(['DOB'],axis=1,inplace=True)
df
# Out:
#      Name   Age
# 0  dharsh    19
# 1   Dhivs  None
# 2    Bava    20
# 3       a     0
# 4       b     0
# 5       D   NaN
# 6  np.nan

# %%
df.drop([0,4])
# Out:
#      Name   Age
# 1   Dhivs  None
# 2    Bava    20
# 3       a     0
# 5       D   NaN
# 6  np.nan

# %%
s
# Out:
# array([1, 2, 3, 4])

# %%
s>2
# Out:
# array([False, False,  True,  True])

# %%
s[s<3]
# Out:
# array([1, 2])

# %%
x=np.array([2,3,4,5,6,7])
x[x%2==0]
# Out:
# array([2, 4, 6])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Age     6 non-null      object
# dtypes: object(2)
# memory usage: 240.0+ bytes

# %%
df['Name'].str.contains('a')
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6     True
# Name: Name, dtype: bool

# %%
'a' in df['Name']
# Out:
# False

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (7, 2)
# 14
# [RangeIndex(start=0, stop=7, step=1), Index(['Name', 'Age'], dtype='object')]
# 2
# Name    object
# Age     object
# dtype: object
# RangeIndex(start=0, stop=7, step=1)
# Index(['Name', 'Age'], dtype='object')
# [['dharsh' 19]
#  ['Dhivs' None]
#  ['Bava' 20]
#  ['a' 0]
#  ['b' 0]
#  ['D' 'NaN']
#  ['np.nan' ' ']]

# %%
df
# Out:
#      Name   Age
# 0  dharsh    19
# 1   Dhivs  None
# 2    Bava    20
# 3       a     0
# 4       b     0
# 5       D   NaN
# 6  np.nan

# %%
df.loc[0,'Name']
# Out:
# 'dharsh'

# %%
df.iloc[1,1]

# %%
df
# Out:
#      Name   Age
# 0  dharsh    19
# 1   Dhivs  None
# 2    Bava    20
# 3       a     0
# 4       b     0
# 5       D   NaN
# 6  np.nan

# %%
df['Age'][1]=34
df
# Out:
#      Name  Age
# 0  dharsh   19
# 1   Dhivs   34
# 2    Bava   20
# 3       a    0
# 4       b    0
# 5       D  NaN
# 6  np.nan

# %% [markdown]
# Reading from file
#
#
# 1.   CSV
# 2.   JSON
# 3.   Excel
# 4.
# 5.   HTML

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/Wikipedia:About")
df
# Out:
# [   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte Basic information on Wikipedia  \
#  0   Help directory menu Teahouse (interactive help...
#  1                                     About Wikipedia
# ...

# %%
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
type(df.item_price)
# Out:
# pandas.core.series.Series

# %%
df.describe(include="all")
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.item_price = df.item_price.str.replace('$','')
df.head(10)
# Out:
# <ipython-input-61-b926718db947>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price = df.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
df.item_price=df.item_price.astype(float)

# %%
type(df.item_price[0])
# Out:
# numpy.float64

# %%
#df.item_price=df.item_price * 100
#df

# %%
df.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
df_drink=df[df.item_price< 1.1]
df_drink
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %%
print(df_drink.item_name.unique())
print(df_drink.item_name.nunique())
# Out:
# ['Canned Soda' 'Bottled Water']
# 2

# %%
df_drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df[df.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
df['choice_description'] = df['choice_description'].fillna('')

# %%
df[df.choice_description.str.contains('Black Beans')].item_name.value_counts() #remove null values
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[(df.item_name=='Chicken Bowl')&(df.item_price <10)]
# Out:
#       order_id  quantity     item_name  \
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# ...        ...       ...           ...
# 4583      1823         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 76    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        8.75
# 78    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 99    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...        8.75
# ...                                                 ...         ...
# ...

# %%
df[(df.item_name=='Chicken Bowl')&(df.item_price <10)].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
df=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[(df.star_rating>8) & (df.content_rating == 'PG')]
# Out:
#      star_rating                                              title  \
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                          Star Wars
# 30           8.6                                      Spirited Away
# 32           8.6                                         Casablanca
# 37           8.6                            Raiders of the Lost Ark
# 47           8.5                                   Taare Zameen Par
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 54           8.5                                 Back to the Future
# 80           8.4         Star Wars: Episode VI - Return of the Jedi
# 85           8.4                                 Lawrence of Arabia
# 97           8.4                                          The Sting
# 101          8.3                    Monty Python and the Holy Grail
# 126          8.3                                                 Up
# ...

# %%
df[(df.star_rating>8) & (df.content_rating == 'PG')].sort_values('duration')
# Out:
#      star_rating                                              title  \
# 236          8.1                                          High Noon
# 101          8.3                    Monty Python and the Holy Grail
# 208          8.1                                         Annie Hall
# 266          8.1                                  A Christmas Story
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 126          8.3                                                 Up
# 160          8.2                           How to Train Your Dragon
# 250          8.1                               In the Mood for Love
# 179          8.2                                 The Princess Bride
# 275          8.1                                      Groundhog Day
# 200          8.1                                        Le Samourai
# 32           8.6                                         Casablanca
# 295          8.1                                    The Truman Show
# ...

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[df.actors_list.str.contains('Tim Robbins')] #actors_list is in list so we use str.contains
# Out:
#      star_rating                     title content_rating   genre  duration  \
# 0            9.3  The Shawshank Redemption              R   Crime       142
# 365          8.0              Mystic River              R   Crime       138
# 611          7.7                Short Cuts              R  Comedy       187
# 693          7.7                The Player              R  Comedy       124
# 819          7.6            Jacob's Ladder              R   Drama       113
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 365     [u'Sean Penn', u'Tim Robbins', u'Kevin Bacon']
# 611  [u'Andie MacDowell', u'Julianne Moore', u'Tim ...
# 693   [u'Tim Robbins', u'Greta Scacchi', u'Fred Ward']
# 819  [u'Tim Robbins', u'Elizabeth Pe\xf1a', u'Danny...

# %%
df[df.actors_list.str.contains('Tim Robbins')].sort_values(['star_rating','duration'])
# Out:
#      star_rating                     title content_rating   genre  duration  \
# 819          7.6            Jacob's Ladder              R   Drama       113
# 693          7.7                The Player              R  Comedy       124
# 611          7.7                Short Cuts              R  Comedy       187
# 365          8.0              Mystic River              R   Crime       138
# 0            9.3  The Shawshank Redemption              R   Crime       142
#
#                                            actors_list
# 819  [u'Tim Robbins', u'Elizabeth Pe\xf1a', u'Danny...
# 693   [u'Tim Robbins', u'Greta Scacchi', u'Fred Ward']
# 611  [u'Andie MacDowell', u'Julianne Moore', u'Tim ...
# 365     [u'Sean Penn', u'Tim Robbins', u'Kevin Bacon']
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %%
df[df.actors_list.str.contains('Tim Robbins')].sort_values(['star_rating','duration'],ascending=(True,False))
# Out:
#      star_rating                     title content_rating   genre  duration  \
# 819          7.6            Jacob's Ladder              R   Drama       113
# 611          7.7                Short Cuts              R  Comedy       187
# 693          7.7                The Player              R  Comedy       124
# 365          8.0              Mystic River              R   Crime       138
# 0            9.3  The Shawshank Redemption              R   Crime       142
#
#                                            actors_list
# 819  [u'Tim Robbins', u'Elizabeth Pe\xf1a', u'Danny...
# 611  [u'Andie MacDowell', u'Julianne Moore', u'Tim ...
# 693   [u'Tim Robbins', u'Greta Scacchi', u'Fred Ward']
# 365     [u'Sean Penn', u'Tim Robbins', u'Kevin Bacon']
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %%
ufo=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.dropna(how="all")
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.dropna(subset=['City','Shape Reported'],how="any").shape #any one from city or shape reported
# Out:
# (15576, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'],how="all").shape #all from city and shape reported
# Out:
# (18237, 5)

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
ufo['Shape Reported'].isnull().sum()
# Out:
# 2644

# %%
a=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
a.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
print(a.beer_servings.mean())
# Out:
# 106.16062176165804

# %%
a[a.continent=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
a[a.continent=='Asia'].beer_servings.agg(['max','min'])
# Out:
# max    247
# min      0
# Name: beer_servings, dtype: int64

# %%
a.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
a.groupby('continent').beer_servings.agg(['mean','max','min'])
# Out:
#                      mean  max  min
# continent
# Africa          61.471698  376    0
# Asia            37.045455  247    0
# Europe         193.777778  361    0
# North America  145.434783  285    1
# Oceania         89.687500  306    0
# South America  175.083333  333   93
